# %%
import tweepy
from textblob import TextBlob
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
# %matplotlib notebook
plt.style.use('fivethirtyeight')

# %%
all_keys = open('twitter_login.txt','r').read().splitlines()

# %%
api_key = all_keys[0]
api_key_secret = all_keys[1]
access_token = all_keys[2]
access_token_secret = all_keys[3]

# %%
authenticator = tweepy.OAuthHandler(api_key,api_key_secret)
authenticator.set_access_token(access_token, access_token_secret)

# %%
api = tweepy.API(authenticator, wait_on_rate_limit = True)

# %%
crypto_currency = 'Dodgecoin'
search = f' #{crypto_currency} -filter:retweets'

# %%
tweet_cursor = tweepy.Cursor(api.search, q = search, lang = 'en', tweet_mode = 'extended').items(300)

# %%
tweets = [tweet.full_text for tweet in tweet_cursor]

# %%
tweets_df = pd.DataFrame(tweets, columns = ['Tweets'])

# %%
for _ , row in tweets_df.iterrows():
    row['Tweets'] = re.sub('http\S+', '', row['Tweets'])
    row['Tweets'] = re.sub('#\S+', '', row['Tweets'])
    row['Tweets'] = re.sub('@\S+', '', row['Tweets'])
    row['Tweets'] = re.sub('\\n', '', row['Tweets'])

# %%
tweets_df['Polarity'] = tweets_df['Tweets'].map(lambda tweet: TextBlob(tweet).sentiment.polarity)
tweets_df['Result'] = tweets_df['Polarity'].map(lambda pol: '+' if pol > 0 else '-')

# %%
positive = tweets_df[tweets_df.Result == '+'].count()['Tweets']
negative = tweets_df[tweets_df.Result == '-'].count()['Tweets']

# %%
plt.bar([0,1], [positive, negative], label = ['Positive', 'Negative'], color = ['green','red'])
plt.legend()
plt.show()
# Out:
# <div id='40989307-f3d9-4094-b7c9-37546db0448e'></div>

# %%
from tweepy import Stream
from tweepy import StreamListener
import json
import csv

# %%
twittes = api.home_timeline()
for tweet in twittes:
    print(tweet.text)
# Out:
# The NTAGI chief also said that vaccination-related rumours are vague and vaccines in India are 95-96 per cent safe.
#
# https://t.co/JFBwICZRmd
# Twitter India grievance redressal officer quits; US-based replacement doesn't meet IT norms… https://t.co/IWH7bZFKHP
# International #Lightningstrikes Safety Day: 7 ways to stay safe when lightning strikes
#
# https://t.co/cK7oelk9k3
# RT @hcikingston: As part of the #IndiaAt75 celebrations, @hcikingston partnered with the Good Samaritan Inn #Kingston to distribute 750 coo…
# V Prez pays tributes to former PM P V Narasimha Rao on his 100th birth anniversary
#
# https://t.co/rV3x1rgXb9
# Delhi Police Special Cell conducted a lie detector test of four accused in the Israel Embassy-Delhi blast case afte… https://t.co/JZ8iExZ9t0
# RT @ShivAroor: ♥️🕷
# Meet Icius tukarami — new species of 🕷 named after Asst Sub-Inspector Tukaram Ombale, Ashoka Chakra, hero of 26/11, resp…
# RT @thehindubiz: Just in | #Sensex rises 139.54 points to 53,064.58 in opening session; #Nifty advances 33.05 points to 15,893.40.
# - PTI
# Ed Sheeran to once again collaborate with BTS, singer reveals details
#
# #EdSheeran #BTS #Butter #MakeItRight
#
# https://t.co/zIiBTMgZAh
# Delhi gyms open with 50% capacity from today as part of easing of COVID19 restrictions
#
# "People are enthusiastic ab… https://t.co/OtqXx5SCP7
# RT @Omkar_Raii: The most powerful #AI chip capable of 36 trillion operations per second developed by @Tesla can revolutionise automated dri…
# Iconic painter Sayed Haider Raza was born on February 22, 1922, in Babaria, Madhya Pradesh, and his centenary year… https://t.co/XWKhHJNsS3
# What caused nearly half the 12-story building to cave in on itself in the wee hours of Thursday has yet to be deter… https://t.co/hwxS97gtNK
# #ExpressOpinion | Is it destiny or self-determination that controls how we navigate the web of life?
#
# Himani A Data… https://t.co/2e1b2v4EWU
# National Conference leader @OmarAbdullah 'unreservedly condemns' the killing of J&amp;K Police officer Fayaz Ahmad, alo… https://t.co/FrtaOzRKAn
# RT @lifestyle_ie: "This could totally pass off as a yummy kheer also," said @anahita_dhondy
#
# https://t.co/IJ9VPJgZ3o
#
# Follow @lifestyle_ie
# Recipe: This hazelnut chiffon cake with chocolate glaze stands tall among the best butter-free baking options https://t.co/tBp8W2CtAr
# Remembering former Prime Minister Shri P. V. Narasimha Rao ji on his birth anniversary.
# #Maharashtra govt removes certain lockdown relaxations from today
#
# https://t.co/g8ij8kdqDg
# Former J&amp;K CM @MehboobaMufti condemns the killing of J&amp;K Police officer Fayaz Ahmad, along with his wife and daught… https://t.co/MTSCQqwOGI

# %%
dogecoin = 0
elon_musk = 0

header_name = ['Dogecoin', 'Elon Musk']
with open('sentiment.csv', 'w') as file:
    writer = csv.DictWriter(file, fieldnames=header_name)
    writer.writeheader()

class Listener(StreamListener):
    
    def on_data(self, data):
        raw_twitts = json.loads(data)
        try:
            tweets = raw_twitts['text']
            
            tweets = ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweets).split())
            tweets = ' '.join(re.sub('RT',' ', tweets).split())
            
            blob = TextBlob(tweets.strip())
            
            global dogecoin
            global elon_musk
            
            doge_sentiment = 0
            elon_sentiment = 0
            
            for sent in blob.sentences:
                if "Dogecoin" in sent and "Elon Musk" not in sent:
                    doge_sentiment = doge_sentiment + sent.sentiment.polarity
                else:
                    elon_sentiment = elon_sentiment + sent.sentiment.polarity
            
            dogecoin = dogecoin + doge_sentiment
            elon_musk = elon_musk + elon_sentiment
            
            with open('sentiment.csv', 'a') as file:
                writer = csv.DictWriter(file, fieldnames=header_name)
                info = {
                    'Dogecoin': dogecoin,
                    'Elon Musk': elon_musk
                }
                writer.writerow(info)
            
            print(tweets)
            print()
        except:
            print('Found an Error')
        
    def on_error(self, status):
        print(status)

# %%
twitter_stream = Stream(authenticator, Listener())
twitter_stream.filter(track = ['Dogecoin', 'Elon Musk'])
# Out:
# My favourite crypto trades are ones where you buy at night set your stop loss and wake up to found out you got st
#
# Happy birthday Elon musk
#
# Happy Birthday Elon Musk Sir ji
#
# Elon Musk s Starlink reaches meme worthy milestone of 69 420 simultaneous active users by
#
# Heart and if you want to see MDRGN dogecoin BEEFS all go to the moon together
#
# I would love to get with some dogecoin community members and influencers Maybe we all can contribute a Certain amount o
#
# You really got all that noggin room for what Can t even understand the vibes bruh li
#
# dogefam DogeFamily dogecoin DogeFather My deck is so old it is splintered and I need some lumber We keep get
#
# FREE 500 giveaway 250 Doge 250 BabyDoge To enter 1 Retweet Like this tweet 2 Follow me
#
#
#
# Let s celebrate the 50th birthday of Elon Musk He s the owner of several companies of SpaceX Tesla The Boring Company
#
# DOJO DOJO will be listed on ZT Exchange soon I wish Elon Musk happy birthday DOJO 1000x Opportunity Liquidit
#
# Happy birthday Elon musk
#
# 125 6000 PHP 1 8M IDR 24 hours Follow and the official coin of Elon Musk s Shiba puppy
#
# Happy birthday Elon Musk HappyBirthdayElonMusk
#
#
#
# Especially alien dual citizeners Rupert Murdoch AUSTRALIA Elon Musk South Africa Ghislaine Maxwell Arnold Schwa
#
# DOJO DOJO will be listed on ZT Exchange soon I wish Elon Musk happy birthday DOJO 1000x Opportunity Liquidit
#
# 125 6000 PHP 1 8M IDR 24 hours Follow and the official coin of Elon Musk s Shiba puppy
#
# Check out last week s Top Trending Tokens in EUROPE Add them to your portfolio and have the latest price movements
#
# Dogecoin outshines Ethereum BNB Cardano and XRP under this condition
#
# This would be amazing Instant purchase from me if this was to come back
#
# France Yes we can Dogecoin Doge
#
# Donald Trump s tax bill in 2017 750 Elon Musk s tax bill in 2018 0 Amazon s tax bill in 2018 0 Average American s
#
# That s why followers shouldn t matter in the Dogecoin community We all see your post and memes We like them all I
#
# Dogecoin is now listed on the App Buy and sell DOGE at true cost with no fees Bank transfer amp c
#
# io Air Drop Happy Birthday Elon The Special Event May this project reach Elon Musk Let us all go to the moon Airdro
#
# 120 to one person in 24 hours Retweet amp Follow amp complete these tasks 1 Go to 2 Sea
#
# alfida Robinhood Robinhood to list Baby DogeCoin on Robinhood Tandatangani Petisi via ID
#
# Dogecoin to the mooooooon
#
# Happy Birthday We love you dogearmy DogeFamily DoOnlyGoodEveryday dogecoin doge
#
# Happy Birthday TAKE DOGECOIN TO 100
#
# asim12 Ohhh Today is the birthday of your inspiration Elon Musk ElonMusk DogeFather HappyBirthdayElon
#
# Happy 50th birthday Can you start accepting DogeCoin for Tesla please I need a new car for your birthday
#
# Dear Mr Elon Musk Please read this message and answer YES or NO please Thank you for y
#
# Abhimanyu HappyBirthdayElon happybirthdayelonmusk Happy birthday DogeFather Mr Elon Musk
#
# Algarnonpride dogecoin dogecoinfamily
#
# se eu ganhasse 1 real pra cada vez que a Lili me fizesse um corte Elon Musk teria inveja de mim
#
#
#
# Happy Birthday Elon Musk DogeFather Dogecoins dogecoin
#
# Combs 1000 Dogecoin to 5 people Just Retweet Pinned and Follow Me Ends in 72 hrs Doge DogeArmy DOGE
#
# Happy birthday dogecoin
#
# Elon Musk s 10 rules for success A Thread
#
# There is no covid death There are only poison vaccine induced deaths The 3rd 4th etc wave can only
#
# Heart and if you want to see MDRGN dogecoin BEEFS all go to the moon together
#
# dogecoin
#
# Dogecoin 1 by s birthday Not financial advice
#
# He is basically looking to do as Elon Musk buy cheap promote it and sell once it gets more value milli
#
# TESLA AND DOGECOIN TO THE MOON AND BEYOND WOOF
#
# solarmoon will be the future If you don t get in on this don t cry to me Crypto binance
#
# Let s celebrate the 50th birthday of Elon Musk He s the owner of several companies of SpaceX Tesla The Boring Company
#
# 120 to one person in 24 hours Retweet amp upvote positive comment on doge dogecoin dogearmy dog
#
# Donald Trump s tax bill in 2017 750 Elon Musk s tax bill in 2018 0 Amazon s tax bill in 2018 0 Average American s
#
# Happy 50th Elon birthday dogecoin doge ElonMusk Tesla SpaceX elonmuskbirthday DogecoinToTheMoon
#
# You re holding strong
#
# Life is short for long term grudges Elon Musk INDIA
#
# official Looking for some numbers Here you go 24000 holders 25000 telegram 15 000 Twitter 20m ATH Audited Tweeted
#
# I had no idea this idiot psycho trushed you unfollowed him long time ago He s a disgrace for the space
#
# Abhimanyu HappyBirthdayElon happybirthdayelonmusk Happy birthday DogeFather Mr Elon Musk
#
# HECO Happy birthday to elon musk
#
# MUST WATCH Happy Birthday Cyberking Musk I Don t Ever Give Up Gangsta s Paradise
#
# Someone should look at all the bull runs crypto has had in the past 10 years and average out how long a bull run has usuall
#
# Elon Reeve Musk Pretoria Sud frica 28 de junio de 1971 es un f sico emprendedor inventor y magnate cont
#
# The next Dogecoin rise has potential to rise by 400 450
#
# 50 anos do g nio contempor neo me leva pra Marte pai posti o Grimes me adota
#
# Elon Musk Is Going Crazy Im Taking This Seriousley xrp XRPCommunity xrpholders
#
# Dogecoin is breaking out
#
# gt gt TREASURE HARUTO YOSHI SingtoPrachaya dogecoin FreePalestine
#
# 125 6000 PHP 1 8M IDR 24 hours Follow and the official coin of Elon Musk s Shiba puppy
#
# Good sports Billy haha have ur viking helmet on Odin hails you and everyone Hund Penger t M nen
#
# debra HAPPY BI HDAY ELON MUSK HappyBirthdayElon happybirthdayelonmusk HappyBirthdayDogeFather I made this f
#
# u want long term use case How about one that doesn t even need crypto to survive
#
# Happy Birthday Elon Musk Wishing you many many more trips around the sun
#
# Dogecoin powering up Iron Doge
#
# chain to the moon with Doge Follow chain Doge dogearmy dogecoin Dogecoins Dogecoin dogeu
#
# feliz aniversario elon musk
#
# DOJO DOJO will be listed on ZT Exchange soon I wish Elon Musk happy birthday DOJO 1000x Opportunity Liquidit
#
# This Twitter account is currently ranked number 1 for the most influential crypto influencer on lunar crush No wonder
#
# If you wanna see all the thought that goes into changing the tx fees for dogecoin by the core devs visit this excellent summ
#
# DOJO DOJO will be listed on ZT Exchange soon I wish Elon Musk happy birthday DOJO 1000x Opportunity Liquidit
#
# Happy Birthday
#
#
#
# Solar Moon The Worlds Most Environment Friendly Crypto Pre Sale starts July 1st Join the Telegram
#
# Elon Musk really was born 69 days after 4 20 and this year its the BIG FIVE ZERO Let s all wish a HAPPY 50t
#
# Happy Birthday DogeFather God bless you crypto god Cryptorocktime
#
# 125 6000 PHP 1 8M IDR 24 hours Follow and the official coin of Elon Musk s Shiba puppy
#
# Happy birthday Elon musk
#
# DOJO DOJO will be listed on ZT Exchange soon I wish Elon Musk happy birthday DOJO 1000x Opportunity Liquidit
#
# Happy Birthday We love you dogearmy DogeFamily DoOnlyGoodEveryday dogecoin doge DogecoinToT
#
# 125 6000 PHP 1 8M IDR 24 hours Follow and the official coin of Elon Musk s Shiba puppy
#
# 125 6000 PHP 1 8M IDR 24 hours Follow and the official coin of Elon Musk s Shiba puppy
#
# 120 to one person in 24 hours Retweet amp Follow amp complete these tasks 1 Go to 2 Sea
#
# But he isn t that big of a celebrity he might secretly be the biggest asshole but my point was more aim
#
# 125 6000 PHP 1 8M IDR 24 hours Follow and the official coin of Elon Musk s Shiba puppy
#
# I told you all that I support Elon and Dogecoin at this time but have stipulated that if these thin
#
# Aibo Inu Airdrop is Live Simply follow the guidelines to Win 1 000 000 AIBO and up to 10X Bonus aiboinutoken doge s
#
# HPBD the dog father s
#
# Dogecoin to the moon doge dogecoin crypto currencie monnaie btc bitcoin doge
#
# FREE 500 giveaway 250 Doge 250 BabyDoge To enter 1 Retweet Like this tweet 2 Follow me
#
# Dogecoin the people s crypto
#
# Dogecoin and Shiba Inu s Rivalry Comes to an End SHIB Removes Doge Killer From its Language
#
# Combs 600 DogeCoin to 5 people who Likes Retweets and Follows Me
#
# 125 6000 PHP 1 8M IDR 24 hours Follow and the official coin of Elon Musk s Shiba puppy
#
# Hoje o completa 50 anos de idade A evolu o de Elon Musk
#
# Heart and if you want to see MDRGN dogecoin BEEFS all go to the moon together
#
#
#
# Ok so who let the dogs out I think it was what you think guys
# Dogecoin growing by the year
#
# DOJO DOJO will be listed on ZT Exchange soon I wish Elon Musk happy birthday DOJO 1000x Opportunity Liquidit
#
# DOJO DOJO will be listed on ZT Exchange soon I wish Elon Musk happy birthday DOJO 1000x Opportunity Liquidit
#
# HappyBirthdayElon the DogeFather dogecoin cryptocurrency the man who revolutionized SpaceX ElonMusk elonmuskbirthday
#
# Ok so who let the dogs out I think it was what you think guys
#
# Let s celebrate the 50th birthday of Elon Musk He s the owner of several companies of SpaceX Tesla The Boring Company
#
# The market cap of DOGE is the equivalent of Bitcoin when it was priced at 820 per coin This is a clear indication that
#
# Elon Musk 50th Birthday Party Animated NFT Lottery ElonMusk NFT NFTart NFTlottery NFTs D
#
# Happy Birthday
#
# 4 Dogecoin
#
# Elon Reeve Musk Pretoria Sud frica 28 de junio de 1971 es un f sico emprendedor inventor y magnate cont
#
# 125 6000 PHP 1 8M IDR 24 hours Follow and the official coin of Elon Musk s Shiba puppy
#
# Ok so who let the dogs out I think it was what you think guys
#
# Iss this really a relates to kindly answer this Is Dogefather
#
# Q8i Binance Bitcoin XRP BitTorrent ICP BTC BNB Car mechanic Elon Musk meets my friend Jack the developer of the world
#
# Abhimanyu HappyBirthdayElon happybirthdayelonmusk Happy birthday DogeFather Mr Elon Musk
#
# DOJO DOJO will be listed on ZT Exchange soon I wish Elon Musk happy birthday DOJO 1000x Opportunity Liquidit
#
# I mean shit I would do the same if I had access to a time machine dogecoin doge dogearmy DogecoinRise DogeTumb
#
# Dear Mr Elon Musk Please read this message and answer YES or NO please Thank you for your answer
#
# again with FACTS dogearmy DogecoinRise DogeStrong
#
# Me af dogecoin doge meme memes
#
# promote earnmoney onlinemarketing makemoney affiliatelink marketing bitcoin dogecoin affiliatemarketing Chec
#
# 120 to one person in 24 hours Retweet amp Follow amp complete these tasks 1 Go to 2 Sea
#
# 125 6000 PHP 1 8M IDR 24 hours Follow and the official coin of Elon Musk s Shiba puppy
#
# Elon Musk s house Then Now
#
# Happy Birthday The Doge Father dogecoin DogeFather ElonMusk
#
# 120 to one person in 24 hours Retweet amp upvote positive comment on doge dogecoin dogearmy dog
#
# It s Elon Musk birthday and he still doesn t know how to shit post down bad
#
# We have 24 hours to get to the top Let s make this a reality safemoon SAFEMOONWALLET SAFEMOON
#
# Here s a great infograph of everything that was discussed during today s SAFEMOON AMA safemoonwallet Safem
#
# Dogecoin is currently trading at 0 2553 For more info download doge price tracker
#
# 125 6000 PHP 1 8M IDR 24 hours Follow and the official coin of Elon Musk s Shiba puppy
#
# Happy Birthday
#
# ritesh Guys it s going to be huge for Babydoge Our inspiration role model hero The Elon Musk Its d Legend s birthday on 28th j
#
# The current value of 1 DOGE in USD is 0 256 up 0 011700 so far today dogecoin
#
# Follow me amp rt if u wanna win 333 dogecoin
#
# thefirst Dogecoin isn t going anywhere Crypto is 97 5 branding and it has effectively established itself as the
#
# onlineshop linkedin twitter facebook instagram tiktok socialmedia pinterest dogecoin reddit tumblr affili
#
# 125 6000 PHP 1 8M IDR 24 hours Follow and the official coin of Elon Musk s Shiba puppy
#
# 33 of Americans have heard about Dogecoin far ahead of Ethereum XRP Binance Coin in popularity
#
# Elon Musk Is Going Crazy Im Taking This Seriousley xrp XRPCommunity xrpholders
#
# Follow me amp rt if u wanna win 333 dogecoin
#
# HappyBirthdayElonMusk many more happy returns of the day Mr Elon Musk wish you all the best for Ur vision and inno
#
# Happy birthday to the architect of tomorrow Never in the history of humankind a single person has been abl
#
# It works 22 531 Ripple XRP coins sent to my Binance account BONUS
#
# twitter facebook instagram linkedin pinterest earnmoney promoting affiliatemarketing Check my website makemo
#
# time to critique The bigger fear is for a tightly laid 5G grid on the ground connected to satellites and able to
#
# If you ve been a part of the dogecoin family for months then you ll understand the bond we all have Pure fun Come
#
# Elon Musk Lives in a 50K 400 Sq Ft PreFab Tiny House Sunfellow Tiny House Resource Page
#
# Follow for the follow back hbar xrp catecoin dogecoin btc ethereum
#
# DOJO DOJO will be listed on ZT Exchange soon I wish Elon Musk happy birthday DOJO 1000x Opportunity Liquidit
#
# 50 for Elon s 50th HappyBirthdayElon dogecoin
#
# Elon Musk Birthday 3 6 67
#
# HAPPY BI HDAY ELON MUSK Enjoy your day YouTube Spotify Best
#
# r Look at good ole Doge taking up 80 of that screen Dogecoin
#
# business businesstools businessgrowth smart freelancer tools manage affiliatemarketing Check my website mak
#
# PUPPYDOGE PRE SALE GIVEAWAY Top prize 5 BTC Bitcoin Second prize 5 x Oculus Quest 2 300 value Third pr
#
# CryptoBull I Will Giveaway 500 Of DOGE To Two People 250 Each In Just 24Hours Retweet amp Like Follow Me With Noti On
#
# I m
#
# Elon Musk 50th Birthday Party Animated NFT Lottery ElonMusk NFT NFTart NFTlottery NFTs DCTD
#
# Happy Birthday sir please please help covid 19 no job my room rint no 6 month ago and my d
#
# Ford Electric Mustang Breaks Quarter Mile Record Challenges Elon Musk To Race
#
# linkedin twitter facebook instagram bitcoin socialmedia pinterest dogecoin onlineshopping deal gift gifts
#
# Elon Musk A Leader with Vision LeadershipFlow Blog CROFT Company
#
# Will dogecoin ever be capped DogeFather ecofriendly DOGE A joke cryptocurrency has risen more than 26 000
#
# DOJO DOJO will be listed on ZT Exchange soon I wish Elon Musk happy birthday DOJO 1000x Opportunity Liquidit
#
# affiliateprogram affiliates ambassdor affiliate affiliatemarketing Check my website makemoney earnmoney affil
#
# Elon Musk reminds Me in some ways of a human being
#
# Let s celebrate the 50th birthday of Elon Musk He s the owner of several companies of SpaceX Tesla The Boring Company
#
# Elon Musk liked a tweet from Tesla Owners of Austin Tesla TSLA
#
# I just hit amp mined 69 dogecoin on my first day on Where s the dogearmy at
#
# IF YOU PA OF THE dogearmy I NEED MY SQUAD TO RETWEET THIS WE NEEDS MORE PEOPLE IN OUR dogecoin FAMILY SO WE
#
# Happy Birthday to Elon Musk
#
# BETA DEFI BSC Binance PancakeSwap Dogecoin Elonmusk amirf
#
# O homi ai
#
# Some people don t like change but you need to embrace change if the alternative is disaster Elon Musk GoodMorningEveryo
#
# Happy Birthday Elon Musk HappyBirthdayElonMusk
#
# Happy birthday to elon musk Wish your dreams come true
#
# Closer and closer by the hour If you do not enter our sweep you will not be in the running for the 16 prizes 1st pri
#
# We are loading for upward Be ready IDEX2 Token holders to the mooooooom IDEX2 dogecoin doge shiba
#
# Happy Birthday We love you dogearmy DogeFamily DoOnlyGoodEveryday dogecoin doge DogecoinToT
#
# 120 to one person in 24 hours Retweet amp upvote positive comment on doge dogecoin dogearmy dog
#
# Claim 120 Worth of HINU tokens for free Like Retweet and Tag 3 friends Airdrop Dog
#
# CryptoNite Happy Birthday Sir I love You Doge PAPADOGE Doge
#
# DOJO DOJO will be listed on ZT Exchange soon I wish Elon Musk happy birthday DOJO 1000x Opportunity Liquidit
#
# 125 6000 PHP 1 8M IDR 24 hours Follow and the official coin of Elon Musk s Shiba puppy
#
# Blocktime Aren t Shiba amp baby dogecoin tokens Only crypto has blocks
#
# thefirst Dogecoin isn t going anywhere Crypto is 97 5 branding and it has effectively established itself as the
#
# Happy birthday The Head ELON or NOLE however you spell it It s inevitable He is the man Happy Birthday to Th
#
# Happy birthday Legend nothing is impossible for uh dogecoin elonmuskbirthday DogeFather https
#
# Happy birthday shiba inu elon musk
#
# I AM 100 FOCUSED ON dogecoin
#
# Happy birth Elon my friend Hope you have a good day Stay safe and enjoy your time with ur family We gonna h
#
# Donald Trump s tax bill in 2017 750 Elon Musk s tax bill in 2018 0 Amazon s tax bill in 2018 0 Average American s
#
# chain to the moon with Doge Follow chain Doge dogearmy dogecoin Dogecoins Dogecoin dogeu
#
# We have officially broke out and hit a new all time high NEWDOGE to the moon baby Let s Go Buy before we list on
#
# 98 of cryptos will fail only the strong will survive Dogecoin
#
# dogecoin
#
# FOGE about to drop some news I heard they ve been working on a new app marketing is coming t
#
# We have officially broke out and hit a new all time high NEWDOGE to the moon baby Let s Go Buy before we list on
# Happy Birthday The Doge Father dogecoin DogeFather ElonMusk
#
# Here you can find Weekly Interviews with successful people Inspired by Elon Musk Donald Trump Grant Cardone O
#
# Let s wish Elon Musk a Happy 50th Bday Sign a message to in the reply of this tweet
#
# Let s wish Elon Musk a Happy 50th Bday Sign a message to in the reply of this tweet
#
# Happy Birthday theDogfather dogecoin dogetothemoon
#
# Happy Birthday Sh Elon Musk god may bless you with more innovative disruption to the world for Greener
#
# Innovative nd unique project people io shab BNB dogecoin btc hashtag
#
# DOGE BEATS GOLDEN AGAIN HE NEEDS TO EAT MORE CUCUMBERS dogecoin dogefam doge
#
# CryptoBull I Will Giveaway 500 Of DOGE To Two People 250 Each In Just 24Hours Retweet amp Like Follow Me With Noti On
#
# 120 to one person in 24 hours Retweet amp upvote positive comment on doge dogecoin dogearmy dog
#
# Dogecoin makes me happy
#
# Here s a great infograph of everything that was discussed during today s SAFEMOON AMA safemoonwallet Safem
#
# money mark elon musk
#
# Happy Birthday Elon Musk The dogearmy HappyBirthdayElonMusk
#
# MR Elon Musk you are so Smart unbelievable SHIBARMY SHIB SHIB shibainu ShibaS
#
# Elon Musk s 10 rules for success A Thread
#
# cbseboardexams2021 CoinbaseOnStockal aespa elaineveddy RCBvsSRH TLP Terrorist icseboardexam2021
#
# Great Project
#
# 5 millones de d lares por un dominio Puede que la finalidad real de no sea la que nos h
#
# DOJO DOJO will be listed on ZT Exchange soon I wish Elon Musk happy birthday DOJO 1000x Opportunity Liquidit
#
# Happy Birthday Elon musk ElonMusk elonmuskbirthday ADA dogecoin DogeFather AcceptDOGE
#
# Elon Musk where is your birth certificate I don t believe you were actually born
#
# 125 6000 PHP 1 8M IDR 24 hours Follow and the official coin of Elon Musk s Shiba puppy
#
# Dogecoin and Shiba Inu s Rivalry Comes to an End SHIB Removes Doge Killer From its Language
#
# Elon Musk really was born 69 days after 4 20 and this year its the BIG FIVE ZERO Let s all wish a HAPPY 50t
#
# DOJO DOJO will be listed on ZT Exchange soon I wish Elon Musk happy birthday DOJO 1000x Opportunity Liquidit
#
# CryptoBull I Will Giveaway 500 Of DOGE To Two People 250 Each In Just 24Hours Retweet amp Like Follow Me With Noti On
#
# Elon Musk is celebrating his 50th birthday Happy50thElon Here s to 50 times spinning around the sun being a beacon of l
#
# Happy birthday Here s my Dogecoin adress send me some it s your 50th birthday D7C1AUUsi3qKmVZQHqKRfS5DGQDkjP7om3
#
# Elon Musk ha decidido no acabar con el hambre mundial el d a de hoy
#
# DOJO DOJO will be listed on ZT Exchange soon I wish Elon Musk happy birthday DOJO 1000x Opportunity Liquidit
#
# Damn I wish I had bought Dogecoin back them
#
# 125 6000 PHP 1 8M IDR 24 hours Follow and the official coin of Elon Musk s Shiba puppy
#
# Happy birthday to elon musk Wish your dreams come true
#
# Future headline Dogecoin used to be a joke
#
# 125 6000 PHP 1 8M IDR 24 hours Follow and the official coin of Elon Musk s Shiba puppy
#
# Shitcoin DOGE is going to 05 cents And it may create a super buying opportunity in Bitcoin
#
# DOJO DOJO will be listed on ZT Exchange soon I wish Elon Musk happy birthday DOJO 1000x Opportunity Liquidi
#
# Dogecoin is breaking out
#
# Despite regulatory uncertainty Indian crypto investment surges 19 900 in one year
#
# FREE 500 giveaway 250 Doge 250 BabyDoge To enter 1 Retweet Like this tweet 2 Follow me
#
# Sonali is talented in her own way We should not expect everyone to be Amir Khan or Elon Musk By
#
# HECO Happy birthday to elon musk
#
# DOJO DOJO will be listed on ZT Exchange soon I wish Elon Musk happy birthday DOJO 1000x Opportunity Liquidit
#
# Happy birthday Elon Musk
#
# Hoje o completa 50 anos de idade A evolu o de Elon Musk
#
# wowowo this is a best airdrop next to the moon binance
#
# Dogecoin Community Maytheforcebewithyou lmaooo
#
# If you ve been a part of the dogecoin family for months then you ll understand the bond we all have Pure fun Come
#
# Hoje o completa 50 anos de idade A evolu o de Elon Musk
#
# Happy Birthday DogeFather God bless you crypto god Cryptorocktime
#
# 2 nsfw xxxnifty nsfw
#
# Very very very happy birthday sir Elon Musk Birthday 3 6
#
# Happy birthday elon musk
#
# 125 6000 PHP 1 8M IDR 24 hours Follow and the official coin of Elon Musk s Shiba puppy
#
# It s s birthday tomorrow so let s celebrate a little early with a giveaway Prizes 500 doge 1
#
# CryptoBull I Will Giveaway 500 Of DOGE To Two People 250 Each In Just 24Hours Retweet amp Like Follow Me With Noti On
#
# 125 6000 PHP 1 8M IDR 24 hours Follow and the official coin of Elon Musk s Shiba puppy
#
# linkedin twitter facebook instagram tiktok socialmedia pinterest dogecoin reddit onlineshopping gift
#
# linkedin twitter facebook instagram tiktok socialmedia pinterest dogecoin reddit deal gift gifts
#
# DOJO DOJO will be listed on ZT Exchange soon I wish Elon Musk happy birthday DOJO 1000x Opportunity Liquidit
#
# Have you heard of this new fragrance It s supposed to give you an air of entrepreneurial ambition It s called El
#
# giftsforher linkedin twitter facebook instagram bitcoin socialmedia pinterest dogecoin deal gift gifts
#
# We have 24 hours to get to the top Let s make this a reality safemoon SAFEMOONWALLET SAFEMOON
#
# Elon Musk you really were born 69 days after 4 20 so over 69 people wish you a very HAPPY 50th Birthday Happy50thE
#
# DOJO DOJO will be listed on ZT Exchange soon I wish Elon Musk happy birthday DOJO 1000x Opportunity Liquidit
#
# socorro elon musk canceriano
#
# Abhimanyu
#
# Happy birthday to elon musk Wish your dreams come true
#
# FLOKI By Elon Musk Telegram Contract Address 0xd959ed57e8c441987a88c0
#
# Will dogecoin ever be capped DogeFather ecofriendly DOGE A joke cryptocurrency has risen more than 26 000
#
#
#
# DOJO DOJO will be listed on ZT Exchange soon I wish Elon Musk happy birthday DOJO 1000x Opportunity Liquidi
#
# We have 24 hours to get to the top Let s make this a reality safemoon SAFEMOONWALLET SAFEMOON
#
# 125 6000 PHP 1 8M IDR 24 hours Follow and the official coin of Elon Musk s Shiba puppy
#
# Dogecoin makes me happy
#
# bank fee donatedogecoin help ElonMusk Bitcoin etherium miamicollapse miamibuilding donate
#
# Happie Birthday Elon Musk Alone Warrior
#
# piyush Happy Birthday Elon Musk The dogearmy loves you
#
# Presale on 19th June 1 PM UTC Presale link SBFM dogecoin ElonMusk shibainu ShibaSwap SH
#
# Retro7 bank fee donatedogecoin help ElonMusk Bitcoin etherium miamicollapse miamibuilding donate cryptocurr
#
# 2 nsfw xxxnifty nsfw
#
# Dogecoin
#
# Icpusdt 6 saatte 25 kazan d n verdi im ctsiusdt 40 verdi Toplam 60 1 g nde kazan survivorGR MasterChef
#
# b baxia GAIA DEFI BSC Binance PancakeSwap Dogecoin Elonmusk
#
# Are you holding your dogecoin long term Yes Yes Yes
#
# DOJO DOJO will be listed on ZT Exchange soon I wish Elon Musk happy birthday DOJO 1000x Opportunity Liquidit
#
# Happy birthday Elon Musk The Papa of Dogecoin DOGE PAPADOGE
#
# DOJO DOJO will be listed on ZT Exchange soon I wish Elon Musk happy birthday DOJO 1000x Opportunity Liquidit
#
# We are loading for upward Be ready IDEX2 Token holders to the mooooooom IDEX2 dogecoin doge shiba shibainu SHI
#
# Nice one
#
# 125 6000 PHP 1 8M IDR 24 hours Follow and the official coin of Elon Musk s Shiba puppy
#
# Hoje o completa 50 anos de idade A evolu o de Elon Musk
#
# Let s wish Elon Musk a Happy 50th Bday Sign a message to in the reply of this tweet
